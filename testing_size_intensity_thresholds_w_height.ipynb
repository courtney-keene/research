# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as ss

# %%
data=pd.read_csv('coh_up_plum_plotter.csv')
data_n=pd.read_csv('coh_up_plum_plotter_new.csv')
data_nv2=pd.read_csv('coh_up_plum_plotter_new_v2.csv')
data_nv3=pd.read_csv('coh_up_plum_plotter_new_v3.csv')
data_nv4=pd.read_csv('coh_up_plum_counter_nv.csv')
data_nv6=pd.read_csv('coh_up_plum_plotter_rooted_updrafts_v2.csv')
data_=pd.read_csv('coh_up_plum_counter_nv7.csv')
print(np.shape(data))
# Out:
# (24, 9)

# %%
# w=0.5 size=4*horiz_thresh
#===============================================
ind = data.iloc[1:,0]
N = data.iloc[1:,1]
norm_height = data.iloc[1:,2]

mchord = data.iloc[1:,3]
mdchord = data.iloc[1:,4]
stdchord = data.iloc[1:,5]


chord_std_error = mchord/((N**(1/2)))
mdchord_std_error = mdchord/((N**(1/2)))

WM = data.iloc[1:,6]
WMD = data.iloc[1:,7]
stdW = data.iloc[1:,8]

W_std_error = WM/((N**(1/2)))
Wmd_std_error = WMD/((N**(1/2)))

# w=0.25 size=4*horiz_thresh
#==============================================
indn = data_n.iloc[1:,0]
Nn = data_n.iloc[1:,1]
norm_heightn = data_n.iloc[1:,2]

mchordn = data_n.iloc[1:,3]
mdchordn = data_n.iloc[1:,4]
stdchordn = data_n.iloc[1:,5]


chord_std_errorn = mchordn/((Nn**(1/2)))
mdchord_std_errorn = mdchordn/((Nn**(1/2)))

WMn = data_n.iloc[1:,6]
WMDn = data_n.iloc[1:,7]
stdWn = data_n.iloc[1:,8]

W_std_errorn = WMn/((Nn**(1/2)))
Wmd_std_errorn = WMDn/((Nn**(1/2)))

# w=0.1 size=4*horiz_thresh
#==============================================
ind_nv2 = data_nv2.iloc[1:,0]
N_nv2 = data_nv2.iloc[1:,1]
norm_height_nv2 = data_nv2.iloc[1:,2]

mchord_nv2 = data_nv2.iloc[1:,3]
mdchord_nv2 = data_nv2.iloc[1:,4]
stdchord_nv2 = data_nv2.iloc[1:,5]


chord_std_error_nv2 = mchord_nv2/((N_nv2**(1/2)))
mdchord_std_error_nv2 = mdchord_nv2/((N_nv2**(1/2)))

WM_nv2 = data_nv2.iloc[1:,6]
WMD_nv2 = data_nv2.iloc[1:,7]
stdW_nv2 = data_nv2.iloc[1:,8]

W_std_error_nv2 = WM_nv2/((N_nv2**(1/2)))
Wmd_std_error_nv2 = WMD_nv2/((N_nv2**(1/2)))

# w=0.1 size=3*horiz_thresh
#==============================================
ind_nv3 = data_nv3.iloc[1:,0]
N_nv3 = data_nv3.iloc[1:,1]
norm_height_nv3 = data_nv3.iloc[1:,2]

mchord_nv3 = data_nv3.iloc[1:,3]
mdchord_nv3 = data_nv3.iloc[1:,4]
stdchord_nv3 = data_nv3.iloc[1:,5]


chord_std_error_nv3 = mchord_nv3/((N_nv3**(1/2)))
mdchord_std_error_nv3 = mdchord_nv3/((N_nv3**(1/2)))

WM_nv3 = data_nv3.iloc[1:,6]
WMD_nv3 = data_nv3.iloc[1:,7]
stdW_nv3 = data_nv3.iloc[1:,8]

W_std_error_nv3 = WM_nv3/((N_nv3**(1/2)))
Wmd_std_error_nv3 = WMD_nv3/((N_nv3**(1/2)))

#w=0.5 size_thresh=3*horiz_thresh
#============================================================
ind_nv4 = data_nv4.iloc[1:,0]
N_nv4 = data_nv4.iloc[1:,1]
norm_height_nv4 = data_nv4.iloc[1:,2]

mchord_nv4 = data_nv4.iloc[1:,3]
mdchord_nv4 = data_nv4.iloc[1:,4]
stdchord_nv4 = data_nv4.iloc[1:,5]


chord_std_error_nv4 = mchord_nv4/((N_nv4**(1/2)))
mdchord_std_error_nv4 = mdchord_nv4/((N_nv4**(1/2)))

WM_nv4 = data_nv4.iloc[1:,6]
WMD_nv4 = data_nv4.iloc[1:,7]
stdW_nv4 = data_nv4.iloc[1:,8]

W_std_error_nv4 = WM_nv4/((N_nv4**(1/2)))
Wmd_std_error_nv4 = WMD_nv4/((N_nv4**(1/2)))


#less qtiles
#===========================================================
data_nv7=pd.read_csv('for_histograms.csv')

ind_nv7 = data_nv7.iloc[:,0]
N_nv7 = data_nv7.iloc[:,1]
norm_height_nv7 = data_nv7.iloc[:,2]

mchord_nv7 = data_nv7.iloc[:,3]
mdchord_nv7 = data_nv7.iloc[:,4]
stdchord_nv7 = data_nv7.iloc[:,5]

WM_nv7 = data_nv7.iloc[:,6]
WMD_nv7 = data_nv7.iloc[:,7]
stdW_nv7 = data_nv7.iloc[:,8]

# w=1 size=4*horiz_thresh
#===============================================
ind__ = data_.iloc[1:,0]
N__ = data_.iloc[1:,1]
norm_height__ = data_.iloc[1:,2]

mchord__ = data_.iloc[1:,3]
mdchord__ = data_.iloc[1:,4]
stdchord__ = data_.iloc[1:,5]


chord_std_error__ = mchord__/((N__**(1/2)))
mdchord_std_error__ = mdchord__/((N__**(1/2)))

WM__ = data_.iloc[1:,6]
WMD__ = data_.iloc[1:,7]
stdW__ = data_.iloc[1:,8]

W_std_error__ = WM__/((N__**(1/2)))
Wmd_std_error__ = WMD__/((N__**(1/2)))

# bottom height <0.4 
#===============================================
data_ru=pd.read_csv('rooted_updrafts_bot.4.csv')
ind_ru = data_ru.iloc[1:,0]
N_ru = data_ru.iloc[1:,1]
norm_height_ru = data_ru.iloc[1:,2]

mchord_ru = data_ru.iloc[1:,3]
mdchord_ru = data_ru.iloc[1:,4]
stdchord_ru = data_ru.iloc[1:,5]

WM_ru= data_ru.iloc[1:,6]
WMD_ru = data_ru.iloc[1:,7]
stdW_ru = data_ru.iloc[1:,8]

# w=1 size=4*horiz_thresh
#===============================================
ind__ = data_.iloc[1:,0]
N__ = data_.iloc[1:,1]
norm_height__ = data_.iloc[1:,2]

mchord__ = data_.iloc[1:,3]
mdchord__ = data_.iloc[1:,4]
stdchord__ = data_.iloc[1:,5]


chord_std_error__ = mchord__/((N__**(1/2)))
mdchord_std_error__ = mdchord__/((N__**(1/2)))

WM__ = data_.iloc[1:,6]
WMD__ = data_.iloc[1:,7]
stdW__ = data_.iloc[1:,8]

W_std_error__ = WM__/((N__**(1/2)))
Wmd_std_error__ = WMD__/((N__**(1/2)))
print(data_ru)
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0            0           0       0.125         NaN         NaN         NaN
# 1            1         124       0.175       112.0       101.0        59.0
# 2            2        1353       0.225       105.0        91.0        67.0
# 3            3        3369       0.275       111.0        88.0        83.0
# 4            4        4342       0.325       117.0        93.0        89.0
# 5            5        4625       0.375       131.0        97.0       119.0
# 6            6        4418       0.425       140.0       103.0       125.0
# 7            7        3938       0.475       163.0       116.0       159.0
# 8            8        3387       0.525       185.0       127.0       177.0
# 9            9        2840       0.575       221.0       152.0       230.0
# 10          10        2586       0.625       263.0       179.0       273.0
# ...

# %%
#==================================================================================
plt.figure(figsize=(12,10))
plt.title('Maximum Updraft Speed vs Chord Length',fontsize=26)
# plt.title('Median Maximum Updraft Speed vs Mean Chord Length',fontsize=24)

WMlow=WM[:15]
mchordlow=mchord[:15]
WMhigh=WM[15:]
mchordhigh=mchord[15:]


plt.scatter(WMlow,mchordlow,label='Below BL',s=90)
slope, intercept, r_value, p_value, std_err = ss.stats.linregress(WMlow,mchordlow)
plt.plot(WMlow, slope*WMlow+intercept,label='r = %.3f' % r_value,lw=3)

plt.scatter(WMhigh,mchordhigh,label='Above BL',s=90)
slope, intercept, r_value, p_value, std_err = ss.stats.linregress(WMhigh,mchordhigh)
plt.plot(WMhigh, slope*WMhigh+intercept,label='r = %.3f' % r_value,lw=3)

# slope, intercept, r_value, p_value, std_err = stats.linregress(WM,mchord)
# plt.plot(WMhigh, slope*WMhigh+intercept,label='r = %.3f' % r_value,color='k',lw=2)

# plt.scatter(WMD,mdchord,color='r',label='')
# slope, intercept, r_value, p_value, std_err = stats.linregress(WMD,mdchord)
# plt.plot(WMD, slope*WMD+intercept,color='r',label='%.3f' % r_value)

plt.xlabel('Mean Maximum Vertical Windspeed [m/s]',fontsize=22)
plt.ylabel('Mean Chord Length of Updraft',fontsize=22)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

plt.legend(fontsize=18)
plt.grid()
# plt.savefig('powerpoint_plots/updraft_vs_length_mean')
# plt.savefig('updraft_vs_length_median')
plt.show()

# %%
#==================================================================================
plt.figure(figsize=(12,10))
plt.title('Maximum Updraft Speed vs Chord Length',fontsize=26)

plt.scatter(WM,mchord,s=90,label='')
slope, intercept, r_value, p_value, std_err = ss.stats.linregress(WM,mchord)
plt.plot(WM, slope*WM+intercept,label='r = %.3f' % r_value,lw=3)

plt.xlabel('Mean Maximum Vertical Windspeed [m/s]',fontsize=22)
plt.ylabel('Mean Chord Length of Updraft',fontsize=22)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

plt.legend(fontsize=18)
plt.grid()

# plt.savefig('powerpoint_plots/updraft_vs_length_mean_new_v2')
# plt.savefig('updraft_vs_length_median')
plt.show()

# %%
### ==================================================================================
plt.figure(figsize=(12,10))
plt.title('Number of Objects vs Height',fontsize=26)

plt.plot(N__[1:],norm_height__[1:],lw=2,label='w=1 size=4*horz_thresh')

plt.plot(N[1:],norm_height[1:],lw=2,label='w=0.5 size=4*horiz_thresh')
plt.plot(N_nv4[1:],norm_height_nv4[1:],lw=2,label='w=0.5 size=3*horz_thresh')

# plt.plot(Nn[1:],norm_heightn[1:],label='w=0.25 size=4*horiz_thresh')
plt.plot(N_nv2[1:],norm_height_nv2[1:],lw=2,label='w=0.1 size=4*horiz_thresh')
plt.plot(N_nv3[1:],norm_height_nv3[1:],lw=2,label='w=0.1 size=3*horiz_thresh')

plt.plot(N_ru[1:],norm_height_ru[1:],lw=2,label='Bottom height < 0.4*Zi')

plt.xlabel('Number of Updraft Objects',fontsize=22)
plt.ylabel('Normalized Height',fontsize=22)
plt.yticks(norm_height,norm_height,fontsize=18)
plt.xticks(fontsize=18)
plt.xlim(500,6000)
plt.legend(fontsize=14,loc='best')
plt.grid()

# plt.savefig('')
plt.savefig('powerpoint_plots/number_objects_changing_thresholds')
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.title('Mean Chord Length',fontsize=26)
# plt.title('Median Chord Length with Standard Error',fontsize=24)

plt.plot(mchord__,norm_height__,lw=2,label='w=1 size=4*horz_thresh')
plt.plot(mchord,norm_height,lw=2,label='w=0.5 size=4*horiz_thresh')
plt.plot(mchord_nv4,norm_height_nv4,lw=2,label='w=0.5 size=3*horz_thresh')
# plt.plot(mchordn,norm_heightn,lw=2,label='w=0.25 size=4*horiz_thresh')

plt.plot(mchord_nv2,norm_height_nv2,lw=2,label='w=0.1 size=4*horiz_thresh')
plt.plot(mchord_nv3,norm_height_nv3,lw=2,label='w=0.1 size=3*horiz_thresh')



plt.ylabel('Normalized Height of the BL',fontsize=22)
plt.xlabel('Mean Chord Length [m]',fontsize=22)
plt.yticks(norm_height,norm_height,fontsize=18)
plt.xticks(fontsize=18)
plt.legend(fontsize=14)
plt.grid()
plt.savefig('powerpoint_plots/mean_chord_changing_thresholds')
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.title('Mean Maximum Updraft', fontsize=26)

plt.plot(WM__,norm_height__,lw=2,label='w=1 size=4*horz_thresh')

plt.plot(WM,norm_height,lw=2,label='w=0.5 size=4*horiz_thresh')
plt.plot(WM_nv4,norm_height_nv4,lw=2,label='w=0.5 size=3*horz_thresh')

# plt.plot(WMn,norm_heightn,label='w=0.25 size=4*horiz_thresh')
plt.plot(WM_nv2,norm_height_nv2,lw=2,label='w=0.1 size=4*horiz_thresh')
plt.plot(WM_nv3,norm_height_nv3,lw=2,label='w=0.1 size=3*horiz_thresh')

plt.ylabel('Normalized Height of the BL',fontsize=22)
plt.xlabel('Mean Maximum Vertical Windspeed [m/s]',fontsize=22)

plt.yticks(norm_height,norm_height,fontsize=18)
plt.xticks(fontsize=18)
plt.legend(fontsize=14)
plt.grid()
plt.savefig('powerpoint_plots/mean_updraft_changing_thresholds')
plt.show()
